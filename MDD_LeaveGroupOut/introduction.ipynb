# %% [markdown]
# <img style="float: left;"  src="https://mtpcloud.oss-cn-shanghai.aliyuncs.com/images/699b1ab5_logo-txt-black.png" width="400px">

# %% [markdown]
# 欢迎您使用矩池云服务，在这里您可以使用 Jupyter Lab 工具进行操作。<br>
#
# Jupyter Lab 是一个交互式的开发运行环境，相比 Jupyter 提供了更好的用户体验，例如可以同时在一个浏览器页面打开编辑多个 Notebook，Ipython console 和 terminal 终端，并且支持预览和编辑更多种类的文件。[点击查看官方文档](https://jupyterlab.readthedocs.io/en/latest/)
#
# **特别提醒：**
#
# **1. 若要长时间训练或运行脚本，矩池云建议您使用 SSH 终端，SSH 比 Jupyter Lab 更稳定。**
#
# **2. 矩池云强烈建议您在使用过程中保存文件至网盘（默认路径 /mnt），以免发生异常时数据丢失。**

# %% [markdown]
# ## 基本操作
# Jupyter Lab 支持 IPython 文件的新建、编辑和运行，您可新建一个IPython文件或打开已有文件，然后点击上方小三角按钮运行。<br>
#
# ![](https://mtpcloud.oss-cn-shanghai.aliyuncs.com/images/1219d6e0_run.png)
# <br>
# 例如您可点击小三角运行以下命令，会输出运行结果"Hello World!"

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## 使用命令行工具
#
# 若您想使用 Bash 命令，您可以使用 Terminal 终端。
# <br>
# 点击左侧边栏上方的 *+* 按钮然后点击 *Terminal* 按钮来打开终端。
# ![](https://mtpcloud.oss-cn-shanghai.aliyuncs.com/images/25992940_terminal.png)
# 在 Terminal 中输入命令。
# ![](https://mtpcloud.oss-cn-shanghai.aliyuncs.com/images/fc6556c7_bash.png)

# %% [markdown]
# ## 网盘挂载
# "我的网盘"中的数据，默认挂载在 mnt 目录下，您可以进入 /mnt 目录查看。
# <br>
# 如果在租用机器时，您有修改自己的网盘挂载目录，则以您自己修改的目录为准。
# <br><br>
# 请注意，**您在该目录下进行的所有操作，等同于直接对"我的网盘"进行操作。**
# <br>
# 例如现在 /mnt 是您的网盘挂载目录，您删除了 /mnt 中的 1.txt 文件，那么在矩池云"我的网盘"中，您的 1.txt 文件也会同步删除，且无法恢复。

# %% [markdown]
# ## 公开数据集
# 矩池云提供了一些常用的公开数据集供您使用，位置在根目录 public 文件夹下。
# <br>
# 您可使用 `cd /public/data` 命令快速使用和访问（只读）。
#
# 公开数据集说明：[点击查看详细说明](https://matpool.com/supports/doc-public-data/)
#
#
# ## Keras 预置模型
#
# 矩池云会在租用机器后自动为您挂载 Keras 预置模型，路径为 `/public/keras_pretrained_model` 。
#
# 使用前，可先将预置模型复制到 Keras 目录，路径为 `~/.keras/models`，例如要使用 Resnet50 模型：
#
# ```
# cp /public/keras_pretrained_model/resnet50_weights_tf_dim_ordering_tf_kernels.h5 ~/.keras/models
# ```
#
# 复制成功后即可在 Python 文件中即可调用该模型。
#
# ```
# from keras.applications.resnet50 import ResNet50
# model = ResNet50(weights='imagenet')
# model.summary()
# ```
